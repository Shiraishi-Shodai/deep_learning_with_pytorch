# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 3.12 テンソルの保存とロード

# %%
import torch

# %% [markdown]
# ## 保存

# %%
points = torch.tensor([[1.0, 2.0], [3.0, 4.0]])
torch.save(points, '/content/drive/MyDrive/PyTorch_Introduction/Chapter3/ourpoints.t')

# %% [markdown]
# ## 読み取り

# %%
points2 = torch.load('/content/drive/MyDrive/PyTorch_Introduction/Chapter3/ourpoints.t')
print(points2)
# Out:
# tensor([[1., 2.],
#         [3., 4.]])
