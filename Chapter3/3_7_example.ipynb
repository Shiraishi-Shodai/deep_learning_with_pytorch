# %% [markdown]
# # 3.7 テンソルの格納状態
# テンソルの全要素はtensor.Strageインスタンスが管理する連続した一次元のメモリに管理されている

# %%
import torch

# %% [markdown]
# ## 3.7.1 ストレージのインデックス化

# %%
points = torch.tensor([[4.0, 1.0], [5.0, 3.0], [2.0, 1.0]])
points.storage()
# Out:
# <ipython-input-3-8575ff47c9e0>:2: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   points.storage()
#  4.0
#  1.0
#  5.0
#  3.0
#  2.0
#  1.0
# [torch.storage.TypedStorage(dtype=torch.float32, device=cpu) of size 6]

# %%
points = torch.tensor([[4.0, 1.0], [5.0, 3.0], [2.0, 1.0]])
points_storage = points.storage()
points_storage[0] = 2.0
points
# Out:
# tensor([[2., 1.],
#         [5., 3.],
#         [2., 1.]])

# %% [markdown]
# ## 3.7.2 torchオブジェクトにしか存在しないメソッド
# * 名前の末尾にアンダースコアがついたメソッドはtorchオブジェクトにしか存在しないメソッドであることを示す
# * 出力変数として新しいテンソルを返すのではなく元のテンソルの中身を変更する

# %%
a = torch.ones(3, 2)

a.zero_()

a
# Out:
# tensor([[1., 1.],
#         [1., 1.],
#         [1., 1.]])
